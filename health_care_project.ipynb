# %%
# !pip install openpyxl

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
health_data_clean=pd.read_csv("C:/Users/owino/Desktop/CSA2025/Healthcare/healthcare/data/health_data_clean.csv")

# %%
health_data_clean.shape
# Out:
# (7257, 15)

# %%
health_data_clean.head(1)
# Out:
#    Unnamed: 0.1  Unnamed: 0 facility_type_name          owner_name  \
# 0             0           2         Dispensary  Ministry of Health
#
#         county constituency ward_name  average_rating keph_level_name  \
# 0  Trans Nzoia     Endebess  Endebess             0.0         Level 2
#
#               lat_long  number_of_beds  number_of_cots  \
# 0  [1.02393, 34.77484]               2               0
#
#    number_of_inpatient_beds  number_of_maternity_beds  \
# 0                         0                         2
#
#    facility_catchment_population
# 0                         5000.0

# %%
# #health_data_clean=health_data.drop(columns=["new_born_unit","admission_status_name","owner_type_name",
#                                             "number_of_hdu_beds","number_of_isolation_beds","number_of_general_theatres",
#                                             "number_of_maternity_theatres","number_of_minor_theatres","number_of_eye_theatres",
#                                             "admission_status_name",
#                                             "sub_county_name","number_of_icu_beds","number_of_emergency_casualty_beds","facility_services","facility_infrastructure"],axis=1)

# %%
health_data_clean.shape
# Out:
# (7257, 15)

# %%
health_data_clean.isnull().sum()
# Out:
# Unnamed: 0.1                        0
# Unnamed: 0                          0
# facility_type_name                  0
# owner_name                          0
# county                              0
# constituency                        0
# ward_name                           0
# average_rating                      0
# keph_level_name                     0
# lat_long                          160
# number_of_beds                      0
# number_of_cots                      0
# number_of_inpatient_beds            0
# number_of_maternity_beds            0
# facility_catchment_population    4180
# dtype: int64

# %%
#health_data_clean.to_csv("C:/Users/user/documents/BOAZ/CSA 2025/csa_project/health_data_clean.csv")

# %%
#health_data_clean.drop(columns = ["Unnamed: 0.1","Unnamed: 0"], inplace = True)

# %%
#health_data_clean.drop(columns = ["Unnamed: 0"], inplace = True)

# %%
health_data_clean.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 facility_type_name          owner_name  \
# 0             0           2         Dispensary  Ministry of Health
# 1             1           3         Dispensary  Ministry of Health
# 2             2           4         Dispensary  Ministry of Health
# 3             3           5         Dispensary  Ministry of Health
# 4             4           6         Dispensary  Ministry of Health
#
#         county constituency   ward_name  average_rating keph_level_name  \
# 0  Trans Nzoia     Endebess    Endebess             0.0         Level 2
# 1  Trans Nzoia     Endebess  Chepchoina             0.0         Level 2
# 2  Trans Nzoia     Endebess    Matumbei             0.0         Level 2
# 3  Trans Nzoia     Endebess    Endebess             0.0         Level 2
# 4  Trans Nzoia     Endebess  Chepchoina             0.0         Level 2
#
#                           lat_long  number_of_beds  number_of_cots  \
# ...

# %%
health_data_clean.isnull().sum()
# Out:
# Unnamed: 0.1                        0
# Unnamed: 0                          0
# facility_type_name                  0
# owner_name                          0
# county                              0
# constituency                        0
# ward_name                           0
# average_rating                      0
# keph_level_name                     0
# lat_long                          160
# number_of_beds                      0
# number_of_cots                      0
# number_of_inpatient_beds            0
# number_of_maternity_beds            0
# facility_catchment_population    4180
# dtype: int64

# %%
mean_fcp = health_data_clean["facility_catchment_population"].mean()

# %%
mean_fcp
# Out:
# np.float64(10417.03054923627)

# %%
median_fcp = health_data_clean["facility_catchment_population"].median()

# %%
median_fcp
# Out:
# np.float64(3220.0)

# %%
health_data_clean.dropna(inplace = True)

# %%
health_data_clean.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 facility_type_name          owner_name  \
# 0             0           2         Dispensary  Ministry of Health
# 1             1           3         Dispensary  Ministry of Health
# 2             2           4         Dispensary  Ministry of Health
# 3             3           5         Dispensary  Ministry of Health
# 4             4           6         Dispensary  Ministry of Health
#
#         county constituency   ward_name  average_rating keph_level_name  \
# 0  Trans Nzoia     Endebess    Endebess             0.0         Level 2
# 1  Trans Nzoia     Endebess  Chepchoina             0.0         Level 2
# 2  Trans Nzoia     Endebess    Matumbei             0.0         Level 2
# 3  Trans Nzoia     Endebess    Endebess             0.0         Level 2
# 4  Trans Nzoia     Endebess  Chepchoina             0.0         Level 2
#
#                           lat_long  number_of_beds  number_of_cots  \
# ...

# %%
health_data_clean.isnull().sum()
# Out:
# Unnamed: 0.1                     0
# Unnamed: 0                       0
# facility_type_name               0
# owner_name                       0
# county                           0
# constituency                     0
# ward_name                        0
# average_rating                   0
# keph_level_name                  0
# lat_long                         0
# number_of_beds                   0
# number_of_cots                   0
# number_of_inpatient_beds         0
# number_of_maternity_beds         0
# facility_catchment_population    0
# dtype: int64

# %%
health_data_clean.describe(include = "all")
# Out:
#         Unnamed: 0.1    Unnamed: 0 facility_type_name          owner_name  \
# count    3053.000000   3053.000000               3053                3053
# unique           NaN           NaN                 21                   7
# top              NaN           NaN         Dispensary  Ministry of Health
# freq             NaN           NaN               2064                2894
# mean     2596.189322   5865.963315                NaN                 NaN
# std      1891.934690   3925.570240                NaN                 NaN
# min         0.000000      2.000000                NaN                 NaN
# 25%       885.000000   2596.000000                NaN                 NaN
# 50%      2344.000000   5618.000000                NaN                 NaN
# 75%      4134.000000   8824.000000                NaN                 NaN
# max      7241.000000  16087.000000                NaN                 NaN
#
#          county constituency ward_name  average_rating keph_level_name  \
# ...

# %% [markdown]
# ## We dropped the intersex in the population since we were only focussing on the specific gender, and the total population

# %%
health_data_aggregate = health_data_clean.groupby('county').agg({
    'average_rating': 'mean',   # You could use other functions like sum, median, etc.
    'number_of_beds': 'sum',
    'number_of_cots': 'sum',
    'number_of_inpatient_beds': 'sum',
    'number_of_maternity_beds': 'sum',
    'facility_catchment_population': 'sum',
    'facility_type_name':'count'
}).reset_index()

# %%
health_data_aggregate.head()
# Out:
#             county  average_rating  number_of_beds  number_of_cots  \
# 0          Baringo        0.003902             284              16
# 1            Bomet        0.012987             157              19
# 2          Bungoma        0.019748             881              67
# 3            Busia        0.012500             523               1
# 4  Elgeyo Marakwet        0.050000             237              23
#
#    number_of_inpatient_beds  number_of_maternity_beds  \
# 0                        15                        19
# 1                        12                        71
# 2                       295                       210
# 3                       219                        83
# 4                         2                        67
#
#    facility_catchment_population  facility_type_name
# 0                       204309.0                  41
# 1                       398032.0                  77
# 2                      1342280.0                 129
# ...

# %%
health_data_aggregate.describe()
# Out:
#        average_rating  number_of_beds  number_of_cots  \
# count       47.000000       47.000000       47.000000
# mean         0.032395      376.914894       40.553191
# std          0.047344      303.196581       34.509487
# min          0.000000        0.000000        0.000000
# 25%          0.002393      136.500000       17.000000
# 50%          0.012900      295.000000       33.000000
# 75%          0.034523      571.000000       62.000000
# max          0.184211     1058.000000      176.000000
#
#        number_of_inpatient_beds  number_of_maternity_beds  \
# count                 47.000000                 47.000000
# mean                 243.255319                107.702128
# std                  784.537262                 90.538225
# min                    0.000000                  0.000000
# 25%                    3.500000                 33.000000
# 50%                   39.000000                 83.000000
# 75%                  154.500000                182.000000
# ...

# %%
health_data_aggregate.rename(columns = {"facility_type_name":"number of facilities"}, inplace = True)

# %%
health_data_aggregate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   county                         47 non-null     object
#  1   average_rating                 47 non-null     float64
#  2   number_of_beds                 47 non-null     int64
#  3   number_of_cots                 47 non-null     int64
#  4   number_of_inpatient_beds       47 non-null     int64
#  5   number_of_maternity_beds       47 non-null     int64
#  6   facility_catchment_population  47 non-null     float64
#  7   number of facilities           47 non-null     int64
# dtypes: float64(2), int64(5), object(1)
# memory usage: 3.1+ KB

# %%
health_data_aggregate.shape
# Out:
# (47, 8)

# %%
census_data_2019 = pd.read_excel("C:/Users/owino/Desktop/CSA2025/Healthcare/healthcare/data/Kenya Population data 2019 census.xlsx");census_data_2019.head(5)
# Out:
#            County    Total    Male  Female  Total.1  Conventional  \
# 0         MOMBASA  1208333  610257  598046   378422        376295
# 1           KWALE   866820  425121  441681   173176        172802
# 2          KILIFI  1453787  704089  749673   298472        297990
# 3      TANA RIVER   315943  158550  157391    68242         66984
# 4            LAMU   143920   76103   67813    37963         34231
#
#    Group quarters  Persons per Sq. Km
# 0            2127         5495.008378
# 1             374          105.022558
# 2             482          115.809472
# 3            1258            8.335430
# 4            3732           22.906165

# %%
census_data_2019.rename(columns = {"County":"county","Total":"total_pop", "Total.1":"hh_total", "Conventional":"hh_conventional","Group quarters":"hh_group_quarters","Persons per Sq. Km":"persons_per_sq_km"}, inplace = True)

# %%
census_data_2019.head()
# Out:
#            county  total_pop    Male  Female  hh_total  hh_conventional  \
# 0         MOMBASA    1208333  610257  598046    378422           376295
# 1           KWALE     866820  425121  441681    173176           172802
# 2          KILIFI    1453787  704089  749673    298472           297990
# 3      TANA RIVER     315943  158550  157391     68242            66984
# 4            LAMU     143920   76103   67813     37963            34231
#
#    hh_group_quarters  persons_per_sq_km
# 0               2127        5495.008378
# 1                374         105.022558
# 2                482         115.809472
# 3               1258           8.335430
# 4               3732          22.906165

# %%
census_data_2019["county"] = census_data_2019["county"].str.title();census_data_2019["county"]
# Out:
# 0                 Mombasa
# 1                   Kwale
# 2                  Kilifi
# 3              Tana River
# 4                    Lamu
# 5            Taita/Taveta
# 6                 Garissa
# 7                   Wajir
# 8                 Mandera
# 9                Marsabit
# 10                 Isiolo
# 11                   Meru
# 12          Tharaka-Nithi
# 13                   Embu
# 14                  Kitui
# 15               Machakos
# 16                Makueni
# 17              Nyandarua
# 18                  Nyeri
# 19              Kirinyaga
# 20               Murang'A
# 21                 Kiambu
# 22                Turkana
# 23             West Pokot
# 24                Samburu
# 25            Trans Nzoia
# 26            Uasin Gishu
# 27        Elgeyo/Marakwet
# 28                  Nandi
# 29                Baringo
# 30               Laikipia
# 31                 Nakuru
# 32                  Narok
# 33                Kajiado
# 34                Kericho
# ...

# %%
census_data_2019_sort =census_data_2019.sort_values(["county"]); census_data_2019_sort
# Out:
#                  county  total_pop     Male   Female  hh_total  \
# 29              Baringo     666763   336322   330428    142518
# 35                Bomet     875689   434287   441379    187641
# 38              Bungoma    1670570   812146   858389    358796
# 39                Busia     893681   426252   467401    198152
# 27      Elgeyo/Marakwet     454480   227317   227151     99861
# 13                 Embu     608599   304208   304367    182743
# 6               Garissa     841353   458975   382344    141394
# 42             Homa Bay    1131950   539560   592367    262036
# 10               Isiolo     268002   139510   128483     58072
# 33              Kajiado    1117840   557098   560704    316179
# 36             Kakamega    1867579   897133   970406    433207
# 34              Kericho     901777   450741   451008    206036
# 21               Kiambu    2417735  1187146  1230454    795241
# 2                Kilifi    1453787   704089   749673    298472
# ...

# %%
census_data_2019_sort.reset_index(inplace = True)

# %%
census_data_2019_sort
# Out:
#     level_0  index               county  total_pop     Male   Female  \
# 0         0     29              Baringo     666763   336322   330428
# 1         1     35                Bomet     875689   434287   441379
# 2         2     38              Bungoma    1670570   812146   858389
# 3         3     39                Busia     893681   426252   467401
# 4         4     27      Elgeyo/Marakwet     454480   227317   227151
# 5         5     13                 Embu     608599   304208   304367
# 6         6      6              Garissa     841353   458975   382344
# 7         7     42             Homa Bay    1131950   539560   592367
# 8         8     10               Isiolo     268002   139510   128483
# 9         9     33              Kajiado    1117840   557098   560704
# 10       10     36             Kakamega    1867579   897133   970406
# 11       11     34              Kericho     901777   450741   451008
# 12       12     21               Kiambu    2417735  1187146  1230454
# ...

# %%
## Merge the dataset for census 2019 with the health_data_aggregated
#census_health_merged = census_data_2019.merge(health_data_aggregate, left_on = "county", right_on = "county")
pd.concat([census_data_2019_sort, health_data_aggregate], axis=1, join="outer")
# Out:
#     level_0  index               county  total_pop     Male   Female  \
# 0         0     29              Baringo     666763   336322   330428
# 1         1     35                Bomet     875689   434287   441379
# 2         2     38              Bungoma    1670570   812146   858389
# 3         3     39                Busia     893681   426252   467401
# 4         4     27      Elgeyo/Marakwet     454480   227317   227151
# 5         5     13                 Embu     608599   304208   304367
# 6         6      6              Garissa     841353   458975   382344
# 7         7     42             Homa Bay    1131950   539560   592367
# 8         8     10               Isiolo     268002   139510   128483
# 9         9     33              Kajiado    1117840   557098   560704
# 10       10     36             Kakamega    1867579   897133   970406
# 11       11     34              Kericho     901777   450741   451008
# 12       12     21               Kiambu    2417735  1187146  1230454
# ...

# %%
final_data = (pd.concat([census_data_2019_sort, health_data_aggregate], axis=1, join="outer")).loc[:,~(pd.concat([census_data_2019_sort, health_data_aggregate], axis=1, join="outer")).columns.duplicated()]

# %%
final_data
# Out:
#     level_0  index               county  total_pop     Male   Female  \
# 0         0     29              Baringo     666763   336322   330428
# 1         1     35                Bomet     875689   434287   441379
# 2         2     38              Bungoma    1670570   812146   858389
# 3         3     39                Busia     893681   426252   467401
# 4         4     27      Elgeyo/Marakwet     454480   227317   227151
# 5         5     13                 Embu     608599   304208   304367
# 6         6      6              Garissa     841353   458975   382344
# 7         7     42             Homa Bay    1131950   539560   592367
# 8         8     10               Isiolo     268002   139510   128483
# 9         9     33              Kajiado    1117840   557098   560704
# 10       10     36             Kakamega    1867579   897133   970406
# 11       11     34              Kericho     901777   450741   451008
# 12       12     21               Kiambu    2417735  1187146  1230454
# ...

# %%
final_data.describe()
# Out:
#          level_0      index     total_pop          Male        Female  \
# count  47.000000  47.000000  4.700000e+01  4.700000e+01  4.700000e+01
# mean   23.000000  23.000000  1.012006e+06  5.010225e+05  5.109514e+05
# std    13.711309  13.711309  6.932427e+05  3.423677e+05  3.513158e+05
# min     0.000000   0.000000  1.439200e+05  7.610300e+04  6.781300e+04
# 25%    11.500000  11.500000  6.095050e+05  3.031095e+05  3.112910e+05
# 50%    23.000000  23.000000  8.936810e+05  4.507410e+05  4.488680e+05
# 75%    34.500000  34.500000  1.156724e+06  5.699920e+05  5.897590e+05
# max    46.000000  46.000000  4.397073e+06  2.192452e+06  2.204376e+06
#
#            hh_total  hh_conventional  hh_group_quarters  persons_per_sq_km  \
# count  4.700000e+01     4.700000e+01          47.000000          47.000000
# mean   2.583811e+05     2.562344e+05        2146.744681         509.162713
# std    2.344552e+05     2.325880e+05        3057.084413        1175.424615
# ...

# %%
final_data.shape
# Out:
# (47, 15)

# %%
final_data.drop(columns = ["level_0","index"], inplace = True);final_data
# Out:
#                  county  total_pop     Male   Female  hh_total  \
# 0               Baringo     666763   336322   330428    142518
# 1                 Bomet     875689   434287   441379    187641
# 2               Bungoma    1670570   812146   858389    358796
# 3                 Busia     893681   426252   467401    198152
# 4       Elgeyo/Marakwet     454480   227317   227151     99861
# 5                  Embu     608599   304208   304367    182743
# 6               Garissa     841353   458975   382344    141394
# 7              Homa Bay    1131950   539560   592367    262036
# 8                Isiolo     268002   139510   128483     58072
# 9               Kajiado    1117840   557098   560704    316179
# 10             Kakamega    1867579   897133   970406    433207
# 11              Kericho     901777   450741   451008    206036
# 12               Kiambu    2417735  1187146  1230454    795241
# 13               Kilifi    1453787   704089   749673    298472
# ...

# %%
final_data.head()
# Out:
#                 county  total_pop    Male  Female  hh_total  hh_conventional  \
# 0              Baringo     666763  336322  330428    142518           141877
# 1                Bomet     875689  434287  441379    187641           187230
# 2              Bungoma    1670570  812146  858389    358796           357714
# 3                Busia     893681  426252  467401    198152           197944
# 4      Elgeyo/Marakwet     454480  227317  227151     99861            99119
#
#    hh_group_quarters  persons_per_sq_km  average_rating  number_of_beds  \
# 0                641          60.699676        0.003902             284
# 1                411         349.286947        0.012987             157
# 2               1082         552.448500        0.019748             881
# 3                208         525.761629        0.012500             523
# 4                742         149.891529        0.050000             237
#
# ...

# %%
## The outcome variable = facility_catchment_population
### The independent variable

# %%
fig,axes=plt.subplots(figsize=(20,6))
sns.barplot(x='county', y='facility_catchment_population', data=final_data)
plt.xticks(rotation=90)  # or rotation=90 for vertical labels
plt.tight_layout()
plt.show()

# %%
figure = save.fig("C:\Users\owino\Desktop\CSA2025\Healthcare\healthcare\data\Output")

# %%
#The number of facilities per county
fig,axes=plt.subplots(figsize=(20,6))
#final_data.plot(kind='bar', x='county', y='number of facilities')

sns.barplot(x='county', y='number of facilities', data=final_data)
plt.xticks(rotation=90)  # or rotation=90 for vertical labels
plt.tight_layout()
plt.show()

# %%
final_data["number_of_beds"].plot.hist(bins = 10)
# Out:
# <Axes: ylabel='Frequency'>

# %%
sns.histplot(data=final_data, x='facility_catchment_population', kde=True)
plt.title('facility_catchment_population')
plt.tight_layout()
plt.show()

# %%
sns.histplot(data=final_data, x='facility_catchment_population', kde=True)
plt.title('facility_catchment_population')
plt.tight_layout()
plt.show()

# %%
sns.histplot(data=final_data, x='facility_catchment_population', kde=True)
plt.title('facility_catchment_population')
plt.tight_layout()
plt.show()

# %%
sns.histplot(data=final_data, x='number_of_beds', kde=True)
plt.title('Distribution of Number of Beds')
plt.tight_layout()
plt.show()

# %%
# Create a visualization
gap=sns.relplot(
    data=final_data,
    x="number of facilities", y="facility_catchment_population", 
    hue="county", size=final_data["total_pop"], sizes=(100,1000),
);
gap.set_axis_labels("The number of facilities", "facility_catchment_populations");

# %%
mean_number_of_beds = final_data["number of facilities"].mean();mean_number_of_beds
# Out:
# np.float64(64.95744680851064)

# %%
# Create a density plot to visualise distribution of real_temp
ax = final_data['number of facilities'].plot.density(title='Distribution of number of facilities', label='number of facilities')

# Get the column mean
mean_number_of_beds = final_data["number of facilities"].mean()

# Plot the column mean
plt.axvline(x=mean_number_of_beds, color='red', linestyle='dashed', label='mean')
ax.legend();

# %%
numeric_data = final_data.select_dtypes(include = 'number')

# %%
# 
corr_matrix = numeric_data.corr()

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Matrix of Numeric Features')
plt.tight_layout()
plt.show()

# %%
## Choosing which variables are more

# %%
#Save the figure
fig.savefig("C:\Users\owino\Desktop\CSA2025\Healthcare\healthcare\data\Output/histplot.png")
